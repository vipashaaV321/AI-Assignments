# %% [markdown]
# <a href="https://colab.research.google.com/github/vipashaaV321/AI-Assignments/blob/master/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/sample_data/AI-DS.csv')
dataset
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
le=LabelEncoder()
label=le.fit_transform(dataset["sex"])
label1=le.fit_transform(dataset["smoker"])

# %%
label2=le.fit_transform(dataset["region"])

# %%
label2
# Out:
# array([3, 2, 2, ..., 2, 3, 1])

# %%
label1
# Out:
# array([1, 0, 0, ..., 0, 0, 1])

# %%
dataset1=dataset
data=pd.get_dummies(dataset1["sex"])
data
# Out:
#       female  male
# 0          1     0
# 1          0     1
# 2          0     1
# 3          0     1
# 4          0     1
# ...      ...   ...
# 1333       0     1
# 1334       1     0
# 1335       1     0
# 1336       1     0
# 1337       1     0
#
# [1338 rows x 2 columns]

# %%
data=dataset.drop('sex',axis='columns')

# %%
data1=data.drop('smoker',axis='columns')

# %%
data1["smoker"]=label

# %%
data1
# Out:
#       age     bmi  children     region      charges  smoker
# 0      19  27.900         0  southwest  16884.92400       0
# 1      18  33.770         1  southeast   1725.55230       1
# 2      28  33.000         3  southeast   4449.46200       1
# 3      33  22.705         0  northwest  21984.47061       1
# 4      32  28.880         0  northwest   3866.85520       1
# ...   ...     ...       ...        ...          ...     ...
# 1333   50  30.970         3  northwest  10600.54830       1
# 1334   18  31.920         0  northeast   2205.98080       0
# 1335   18  36.850         0  southeast   1629.83350       0
# 1336   21  25.800         0  southwest   2007.94500       0
# 1337   61  29.070         0  northwest  29141.36030       0
#
# [1338 rows x 6 columns]

# %%
data1["sex"]=label
data1
# Out:
#       age     bmi  children     region      charges  smoker  sex
# 0      19  27.900         0  southwest  16884.92400       0    0
# 1      18  33.770         1  southeast   1725.55230       1    1
# 2      28  33.000         3  southeast   4449.46200       1    1
# 3      33  22.705         0  northwest  21984.47061       1    1
# 4      32  28.880         0  northwest   3866.85520       1    1
# ...   ...     ...       ...        ...          ...     ...  ...
# 1333   50  30.970         3  northwest  10600.54830       1    1
# 1334   18  31.920         0  northeast   2205.98080       0    0
# 1335   18  36.850         0  southeast   1629.83350       0    0
# 1336   21  25.800         0  southwest   2007.94500       0    0
# 1337   61  29.070         0  northwest  29141.36030       0    0
#
# [1338 rows x 7 columns]

# %%
data2=data1.drop('region',axis='columns')

# %%
data2["region"]=label2
data2
# Out:
#       age     bmi  children      charges  smoker  sex  region
# 0      19  27.900         0  16884.92400       0    0       3
# 1      18  33.770         1   1725.55230       1    1       2
# 2      28  33.000         3   4449.46200       1    1       2
# 3      33  22.705         0  21984.47061       1    1       1
# 4      32  28.880         0   3866.85520       1    1       1
# ...   ...     ...       ...          ...     ...  ...     ...
# 1333   50  30.970         3  10600.54830       1    1       1
# 1334   18  31.920         0   2205.98080       0    0       0
# 1335   18  36.850         0   1629.83350       0    0       2
# 1336   21  25.800         0   2007.94500       0    0       3
# 1337   61  29.070         0  29141.36030       0    0       1
#
# [1338 rows x 7 columns]

# %%
data2['charges']=round(data2['charges'],1)
data2
# Out:
#       age     bmi  children  charges  smoker  sex  region
# 0      19  27.900         0  16884.9       0    0       3
# 1      18  33.770         1   1725.6       1    1       2
# 2      28  33.000         3   4449.5       1    1       2
# 3      33  22.705         0  21984.5       1    1       1
# 4      32  28.880         0   3866.9       1    1       1
# ...   ...     ...       ...      ...     ...  ...     ...
# 1333   50  30.970         3  10600.5       1    1       1
# 1334   18  31.920         0   2206.0       0    0       0
# 1335   18  36.850         0   1629.8       0    0       2
# 1336   21  25.800         0   2007.9       0    0       3
# 1337   61  29.070         0  29141.4       0    0       1
#
# [1338 rows x 7 columns]

# %%
X = data2.iloc[:,1:5].values
y = data2.iloc[:,5].values
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y1 = encoder.fit_transform(y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y1_train,y1_test = train_test_split(X,y,test_size=0.2, random_state=3)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers  import SGD, Adam
model = Sequential()
model.add(Dense(10, input_shape=(4,), activation='tanh'))
model.add(Dense(10, activation='softmax'))
model.add(Dense(10, activation='softmax'))
model.add(Dense(1, activation='sigmoid'))
model.compile(Adam(lr=1e-5), 'categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 10)                50
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 11
# ...
# Total params: 281
# Trainable params: 281
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y1_train,epochs = 100)
y_pred=model.predict(X_test)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 0s 1ms/step - loss: 5.9605e-08 - accuracy: 0.5000
# Epoch 2/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.9605e-08 - accuracy: 0.5000
# Epoch 3/100
# 34/34 [==============================] - 0s 1ms/step - loss: 5.9605e-08 - accuracy: 0.5000
# Epoch 4/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.9605e-08 - accuracy: 0.5000
# Epoch 5/100
# 34/34 [==============================] - 0s 1ms/step - loss: 5.9605e-08 - accuracy: 0.5000
# Epoch 6/100
# 34/34 [==============================] - 0s 1ms/step - loss: 5.9605e-08 - accuracy: 0.5000
# Epoch 7/100
# 34/34 [==============================] - 0s 1ms/step - loss: 5.9605e-08 - accuracy: 0.5000
# Epoch 8/100
# 34/34 [==============================] - 0s 1ms/step - loss: 5.9605e-08 - accuracy: 0.5000
# Epoch 9/100
# 34/34 [==============================] - 0s 2ms/step - loss: 5.9605e-08 - accuracy: 0.5000
# Epoch 10/100
# ...
